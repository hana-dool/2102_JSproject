# %%
import pandas as pd

# %%
import csv
import json

with open('final_raw.csv',encoding="utf-8") as f:
    reader = csv.DictReader(f)
    rows = list(reader)

with open('final_raw.json', 'w') as f:
    json.dump(rows, f)

# %%
pd.read_json('final_raw.json')
# Out:
#             index              시설명                소재지도로명주소  \
# 0        0      0        수서종합사회복지관    서울특별시 강남구 광평로 56길 11
# 1        1      1        대청종합사회복지관   서울특별시 강남구 양재대로 55길 10
# 2        2      2    세곡리엔파크4단지 경로당    서울특별시 강남구 헌릉로590길 88
# 3        3      3            대청경로당    서울특별시 강남구 개포로124길 24
# 4        4      4   대치1단지(일원2) 경로당    서울특별시 강남구 개포로 109길 5
# ...    ...    ...              ...                     ...
# 1405  1405   1437          늘푸른노인대학     경상남도 사천시 용현면 용치로 12
# 1406  1406   1438             개웅교회  서울특별시 구로구 개봉로20길 91-10
# 1407  1407   1439           중국동포의집    서울특별시 구로구 남부순환로 1307
# 1408  1408   1440  한국지체장애인협회 구로구지회    서울특별시 구로구 디지털로19길 24
# 1409  1409   1441      한국장애인문화인쇄협회      서울특별시 구로구 경서로9길 35
#
#                      소재지지번주소           운영기관명          전화번호            급식장소  \
# 0          서울특별시 강남구 수서동 723       수서종합사회복지관   02-451-7244       수서종합사회복지관
# 1          서울특별시 강남구 일원동 711       대청종합사회복지관   02-459-6332       대청종합사회복지관
# ...
